# %%
                                      #Task 1 - Fitbit Dataset

# %%
import pandas as pd

# %%
#1.Read this dataset in pandas
df=pd.read_csv(r'D:\task\Fitbit_data.csv')

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df.dtypes
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
df['ActivityDate']
# Out:
# 0      3/25/2016
# 1      3/26/2016
# 2      3/27/2016
# 3      3/28/2016
# 4      3/29/2016
#          ...
# 452     4/8/2016
# 453     4/9/2016
# 454    4/10/2016
# 455    4/11/2016
# 456    4/12/2016
# Name: ActivityDate, Length: 457, dtype: object

# %%
#3.convert all the dates avaible in dataset to timestamp format in pandas
df['converted_date']=pd.to_datetime(df['ActivityDate'])

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
#4.Find out in this data that how many unique id's we have
len(df['Id'].value_counts())
# Out:
# 35

# %%
df['Id'].nunique()
# Out:
# 35

# %%
#5.which id is one of the active id that you have in whole dataset
df[df['Calories']==df['Calories'].max()]
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 138  2891001357     4/1/2016           0            0.0              0.0
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 138                  4.828032                 0.0                       0.0
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 138                  0.0                      0.0                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 138                  660                     0               780      4562
#
#     converted_date
# 138     2016-04-01

# %%
#7.Find out who is the laziest person id that we have in dataset
lazyindex=df[df['Calories']==df['Calories'].min()]['Id'].index
df.loc[lazyindex,['Id','Calories']]
# Out:
#              Id  Calories
# 134  2873212765         0
# 240  4319703577         0
# 290  4702921684         0
# 323  6117666160         0
# 412  8253242879         0

# %%
df['converted_month']=df['converted_date'].dt.month

# %%
df['converted_year']=df['converted_date'].dt.year

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
#8.Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy person we have in our dataset. 
c=df.groupby('Id')['Calories'].sum()
ind=c.ge(30000).index
len(ind)
# Out:
# 35

# %%
#12.what is a total acumulative calories burn for a person find out
df2=df.groupby('Id')['Calories'].sum()
pd.Series.sort_values(df2,ascending=False)
# Out:
# Id
# 4020332650    98412
# 4057192912    60913
# 4702921684    42322
# 8877689391    41414
# 8378563200    40274
# 5577150313    36303
# 1503960366    34128
# 8053475328    31825
# 4445114986    31617
# 7007744171    31525
# 2347167796    30320
# 2022484408    29704
# 6962181067    29249
# 1644430081    29164
# 1927972279    27048
# 7086361926    26124
# 1624580081    25705
# 8792009665    24884
# 6775888955    24523
# 4319703577    23931
# 4558609924    21962
# 6290855005    21656
# 5553957443    21630
# 6117666160    20993
# 2873212765    20349
# 1844505072    19391
# 8583815059    19130
# 3372868164    18603
# 2320127002    18385
# 2891001357    18187
# 8253242879    17556
# 3977333714    16777
# 2026352035    16266
# 6391747486    15868
# 4388161847    14442
# Name: Calories, dtype: int64

# %%
#10.who is the third most active person in this dataset find out those in pandas
l=df['Calories'].nlargest(3).index
df.loc[l[2]]['Id']
# Out:
# 5577150313

# %%
#11.Who is the 5th most laziest person avilable in dataset find it out 
data=df.loc[df[['Calories']].any(axis=1)]
df.loc[data['Calories'].nsmallest(5).index[4]]['Id']
# Out:
# 2347167796

# %%
#6.how many of them have not logged there activity find out in terms of number of ids 
len(df[df['Calories'] == 0])
# Out:
# 5

# %%
#9.How many person are not a regular person with respect to activity try to find out those

# %%
pip install "pymongo[srv]"
# Out:
# ...
#   Using cached dnspython-2.2.1-py3-none-any.whl (269 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#1.Read this dataset in mongodb
import pymongo
client = pymongo.MongoClient("mongodb+srv://praneeth:simhachary@praneeth.cpzwahk.mongodb.net/?retryWrites=true&w=majority")
db = client.test
database = client['Fitbit']
collection=database['Fitbit_userdata']

# %%
import pandas as pd
df=pd.read_csv(r'D:\task\Fitbit_data.csv')

# %%
df.rename(index=lambda X:str(X),inplace=True)

# %%
js=df.to_dict()

# %%
js
# Out:
# {'Id': {'0': 1503960366,
#   '1': 1503960366,
#   '2': 1503960366,
#   '3': 1503960366,
#   '4': 1503960366,
#   '5': 1503960366,
#   '6': 1503960366,
#   '7': 1503960366,
#   '8': 1503960366,
#   '9': 1503960366,
#   '10': 1503960366,
#   '11': 1503960366,
#   '12': 1503960366,
#   '13': 1503960366,
#   '14': 1503960366,
#   '15': 1503960366,
#   '16': 1503960366,
#   '17': 1503960366,
#   '18': 1503960366,
#   '19': 1624580081,
#   '20': 1624580081,
#   '21': 1624580081,
#   '22': 1624580081,
#   '23': 1624580081,
#   '24': 1624580081,
#   '25': 1624580081,
#   '26': 1624580081,
#   '27': 1624580081,
#   '28': 1624580081,
#   '29': 1624580081,
#   '30': 1624580081,
#   '31': 1624580081,
#   '32': 1624580081,
#   '33': 1624580081,
#   '34': 1624580081,
#   '35': 1624580081,
#   '36': 1624580081,
#   '37': 1624580081,
#   '38': 1644430081,
#   '39': 1644430081,
#   '40': 1644430081,
#   '41': 1644430081,
#   '42': 1644430081,
#   '43': 1644430081,
#   '44': 1644430081,
# ...

# %%
collection.insert_many([js])

# %%
                                         #task 2 - Superstore_USA

# %%
import pandas as pd

# %%
dft1=pd.read_excel(r"D:\task\Superstore_USA.xlsx")

# %%
dft1
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
dft2=pd.read_excel(r"D:\task\Superstore_USA.xlsx",sheet_name="Returns")

# %%
dft2
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
dft3=pd.read_excel(r"D:\task\Superstore_USA.xlsx",sheet_name="Users")

# %%
dft3
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
#4.try  to join order and return data both in sql and pandas
newdf=pd.merge(dft1,dft2,how='left')

# %%
#3.Find out how return that we have recived and with a product id 
newdf[newdf['Status']=='Returned']['Order ID']
# Out:
# 49       9895
# 317     13959
# 318     13959
# 324     36038
# 733     39490
#         ...
# 8463     7107
# 8464     7107
# 8465    42823
# 8501    13638
# 8986    47109
# Name: Order ID, Length: 98, dtype: int64

# %%
#5.Try to find out how many unique customer that we have
newdf['Customer Name'].nunique()
# Out:
# 2703

# %%
#1.load this data in sql and in pandas with a relation in sql 
finaldataset=pd.merge(newdf,dft3,how='left')

# %%
#6.try to find out in how many regions we are selling a product and who is a manager for a respective region
finaldataset.groupby(['Region','Manager'])['Row ID'].count()
# Out:
# Region   Manager
# Central  Chris      2899
# East     Erin       2289
# South    Sam        1954
# West     William    2284
# Name: Row ID, dtype: int64

# %%
#7.find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset
total=finaldataset['Ship Mode'].count()
finaldataset.groupby('Ship Mode')['Row ID'].count()/total*100
# Out:
# Ship Mode
# Delivery Truck    13.611288
# Express Air       11.744112
# Regular Air       74.644600
# Name: Row ID, dtype: float64

# %%
finaldataset.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Order ID                         int64
# ...

# %%
#8.Create a new coulmn and try to find our a diffrence between order date and shipment date
import numpy as np
finaldataset['Days_taken_to_ship']=((finaldataset['Ship Date'].sub(finaldataset['Order Date']))/np.timedelta64(1, 'D'))

# %%
finaldataset['Days_taken_to_ship']=finaldataset['Days_taken_to_ship'].astype('int64')

# %%
finaldataset
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
#9.base on question number 8 find out for which order id we have shipment duration more than 10 days 
finaldataset[finaldataset['Days_taken_to_ship'] > 10]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 643    18246       Critical      0.05       11.09           5.25          250
# 1548   23091         Medium      0.04      100.98           7.18          595
# 1549   23092         Medium      0.09        6.48           7.49          595
# 1678   20703  Not Specified      0.07      130.98          30.00          637
# 1679   20704  Not Specified      0.09       55.98           4.86          637
# 1680   20705  Not Specified      0.08      115.99           4.23          637
# 1697    2703  Not Specified      0.07      130.98          30.00          640
# 1698    2704  Not Specified      0.09       55.98           4.86          640
# 1699    2705  Not Specified      0.08      115.99           4.23          640
# 2515   18060            Low      0.02        2.21           1.00          964
# 5548   21603  Not Specified      0.02        5.58           1.99         2048
# ...

# %%
#10.Try to find out a list of a returned order which sihpment duration was more then 6 days and find out that region manager as well
finaldataset[(finaldataset['Days_taken_to_ship'] > 6) & (finaldataset['Status']=='Returned')]['Manager']
# Out:
# 2466    William
# 3232       Erin
# 8251    William
# Name: Manager, dtype: object

# %%
#11.Gorup by region and find out which region is more profitable 
finaldataset.groupby('Region')['Profit'].sum()
# Out:
# Region
# Central    519825.567067
# East       377566.186045
# South      104201.192420
# West       310849.453897
# Name: Profit, dtype: float64

# %%
#12.Try to find out overalll in which country we are giving more didscount 
finaldataset[finaldataset['Discount']==finaldataset['Discount'].max()]['State or Province']
# Out:
# 8649    Illinois
# Name: State or Province, dtype: object

# %%
#13 . Give me a list of unique postal code 
a=finaldataset['Postal Code'].value_counts().index
a
# Out:
# Int64Index([10177, 90049, 20016, 60601, 90045,  2113, 98115, 90041, 30318,
#             77070,
#             ...
#              2116,  6795,  2891,  2050,  6708, 20602,  1757,  6241,  6488,
#              2638],
#            dtype='int64', length=1697)

# %%
#14 . which customer segement is more profitalble find it out .
finaldataset[finaldataset['Profit']==finaldataset['Profit'].max()]['Customer Segment']
# Out:
# 9132    Home Office
# Name: Customer Segment, dtype: object

# %%
#15 . try to find out the 10th most loss making product catagory 
finaldataset.iloc[finaldataset['Profit'].nsmallest(10).index[9]]['Product Category']
# Out:
# 'Technology'

# %%
#16 . Try to find out 10 top  product with highest margins 
g=finaldataset['Profit'].nlargest(10).index

# %%
finaldataset.loc[g,['Product Category']]
# Out:
#      Product Category
# 9132  Office Supplies
# 4189  Office Supplies
# 9404  Office Supplies
# 4642  Office Supplies
# 859        Technology
# 929        Technology
# 5677       Technology
# 3017  Office Supplies
# 1334       Technology
# 2926       Technology
